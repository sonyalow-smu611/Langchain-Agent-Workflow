# %% [markdown]
# 01. What are we building?
# 02. LLM
# 03. Agent
# 04. Tools
# 05. Structured output
# 06. State
# 07. Director → Architect
# 08. Parallel FE + BE
# 09. QA
# 10. Conditional routing
# 11. Repair loop
# 12. HITL
# 13. Full workflow
