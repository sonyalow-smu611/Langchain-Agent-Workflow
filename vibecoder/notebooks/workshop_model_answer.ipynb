# %% [markdown]
# # Workshop Skeleton (Blank)
#
# This is an empty structure for live-coding the vibecoder multi-agent workflow from scratch, following the numbered progression below. It's not a finished example — for a working reference, read the actual source in `vibecoder/src/` instead, starting at `src/graph/graph.py` (which shows how much of this workflow is wired up so far — currently just director → architect).

# %% [markdown]
# 01. What are we building?
# 02. LLM
# 03. Agent
# 04. Tools
# 05. Structured output
# 06. State
# 07. Director → Architect
# 08. Parallel FE + BE
# 09. QA
# 10. Conditional routing
# 11. Repair loop
# 12. HITL
# 13. Full workflow
